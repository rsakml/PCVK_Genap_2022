# %% [markdown]
# <a href="https://colab.research.google.com/github/rsakml/PCVK_Genap_2022/blob/main/Week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import numpy as np
import PIL
import io
import html
import time
# %matplotlib inline
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from base64 import b64decode, b64encode

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

def convertToGRAY(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# **Face Detection**

# %%
jokowi = cv2.imread('/content/drive/MyDrive/Pengolahan Citra/p12/Face Detection/jokowi.jpg')
jokowi_rgb = convertToRGB(jokowi)
jokowi_fd = jokowi_rgb.copy()

kartini = cv2.imread('/content/drive/MyDrive/Pengolahan Citra/p12/Face Detection/kartini.jpg',0)
kartini_rgb = convertToRGB(kartini)
kartini_fd = kartini_rgb.copy()

kucing = cv2.imread('/content/drive/MyDrive/Pengolahan Citra/p12/Face Detection/mycat.jpg',0)
kucing_rgb = convertToRGB(kucing)
kucing_fd = kucing_rgb.copy()

mask = cv2.imread('/content/drive/MyDrive/Pengolahan Citra/p12/Face Detection/mask.png',0)
mask_rgb = convertToRGB(mask)
mask_fd = mask_rgb.copy()

mjordan = cv2.imread('/content/drive/MyDrive/Pengolahan Citra/p12/Face Detection/mjordan.jpg',0)
mjordan_rgb = convertToRGB(mjordan)
mjordan_fd = mjordan_rgb.copy()

solvayconf = cv2.imread('/content/drive/MyDrive/Pengolahan Citra/p12/Face Detection/solvayconf.jpg',0)
solvayconf_rgb = convertToRGB(solvayconf)
solvayconf_fd = solvayconf_rgb.copy()

# %%
cascade_wajah = cv2.CascadeClassifier('/content/drive/MyDrive/Pengolahan Citra/p12/Face Detection/haarcascade_frontalface_alt.xml')
def newFaceCascadeFunction(image_rgb, image):
  fd_image = cascade_wajah.detectMultiScale(image)
  for(x,y,w,h) in fd_image:
    cv2.rectangle(image, (x,y),(x+w,y+h), (0,255,0), 3)
  plt.figure(figsize = (10,10))
  f, axarr = plt. subplots(1,2,figsize=(8,8))
  plt.subplot(121),plt.imshow(image_rgb)
  plt.subplot(122),plt.imshow(image)
  plt.show()

# %%
newFaceCascadeFunction(jokowi_rgb, jokowi_fd)
newFaceCascadeFunction(kartini_rgb, kartini_fd)
newFaceCascadeFunction(kucing_rgb, kucing_fd)
newFaceCascadeFunction(mask_rgb, mask_fd)
newFaceCascadeFunction(mjordan_rgb, mjordan_fd)
newFaceCascadeFunction(solvayconf_rgb, solvayconf_fd)

# %% [markdown]
# Pada Soal No.2. wajah kucing tidak bisa dideteksi dengan baik. Lakukan deteksi wajah
# kucing hingga muncul rectangle pada bagian wajahnya seperti gambar berikut.
# Petunjuk pada soal ini, perhatikan pretrained features yang telah disediakan OpenCV.
# Gunakan xml yang ada jika memang telah disediakan. Jika belum ada, coba cari
# dengan searching melalui search engines.

# %%
cascade_wajah = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalcatface.xml")

kucing_img2 = cv2.imread('/content/drive/MyDrive/Pengolahan Citra/p12/Face Detection/mycat.jpg', 0)

roi_wajah = cascade_wajah.detectMultiScale(kucing_img2)
for (x,y,w,h) in roi_wajah: 
  cv2.rectangle(kucing_img2,  (x, y), (x+w, y+h), (0, 255, 0), 3) 

plt.figure(figsize = (10, 10))

f, axarr = plt.subplots(1, 2, figsize=(15,5))
plt.subplot(111), plt.imshow(convertToRGB(kucing_img2))
plt.show()
# Out:
# <ipython-input-15-3a0b18d9fdd5>:12: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(111), plt.imshow(convertToRGB(kucing_img2))

# %% [markdown]
# Cobakan juga untuk eyes detection pada gambar Jokowi.jpg, sehingga menghasilkan
# gambar seperti berikut.

# %% [markdown]
# Lakukan Face Tracking menggunakan Google Colab. Petunjuk, Tutorial selengkapnya
# tentang akses kamera dan FaceDetection pada google colab

# %% [markdown]
# Lakukan deteksi bagian wajah gambar “mjordan.jpg”, kemudian tindih bagian wajah
# tersebut dengan gambar “smile.png”.

# %% [markdown]
# Lakukan deteksi wajah dengan menggunakan bounding box berwarna hitam, deteksi
# mata menggunakan bounding box berwarna putih, dan deteksi mata kanan
# menggunakan bounding box berwarna merah. Gunakan gambar “people.jpg” untuk
# mengerjakan soal pada nomor ini.
